# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### Sentence
sent=[ "the glass of milk",
      "the glass of juice",
      "the cup of tea",
      "I am a good boy",
      "i am a developer",
      "understand the meaning of words",
      "your videos are good"

]
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'i am a developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[4652, 613, 9082, 5631],
#  [4652, 613, 9082, 3330],
#  [4652, 8062, 9082, 3532],
#  [6387, 5425, 5778, 9040, 7534],
#  [6387, 5425, 5778, 1602],
#  [3717, 4652, 3602, 9082, 3586],
#  [4945, 1102, 3989, 9040]]

# %%
## Word Embedding Representation

import numpy as np
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
## Pre is used to add zeroes at the beginning and Post is used to add zeroes at the end
print(embedded_docs)
# Out:
# [[   0    0    0    0 4652  613 9082 5631]
#  [   0    0    0    0 4652  613 9082 3330]
#  [   0    0    0    0 4652 8062 9082 3532]
#  [   0    0    0 6387 5425 5778 9040 7534]
#  [   0    0    0    0 6387 5425 5778 1602]
#  [   0    0    0 3717 4652 3602 9082 3586]
#  [   0    0    0    0 4945 1102 3989 9040]]

# %%
### Feature Representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# c:\code\Python\venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# array([[[ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.01345137,  0.03700818, -0.00285297, -0.03146731,
#          -0.01209704,  0.0461374 , -0.04498342,  0.01002345,
#           0.04747726,  0.04176629],
#         [ 0.00119399,  0.03558684, -0.04989338, -0.01004828,
#           0.00660592,  0.04408484, -0.01178395, -0.04920936,
#          -0.01163397, -0.03805806],
#         [ 0.04297458,  0.01189159, -0.0050053 , -0.04789938,
#           0.04033569, -0.02460725, -0.02637721,  0.03578104,
#           0.00376084, -0.04058083],
#         [-0.0254133 , -0.03385741,  0.02221021, -0.01097144,
#           0.01635785, -0.03091173,  0.00335266,  0.00777688,
#           0.02525807,  0.0058605 ]],
#
#        [[ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.01345137,  0.03700818, -0.00285297, -0.03146731,
#          -0.01209704,  0.0461374 , -0.04498342,  0.01002345,
#           0.04747726,  0.04176629],
#         [ 0.00119399,  0.03558684, -0.04989338, -0.01004828,
#           0.00660592,  0.04408484, -0.01178395, -0.04920936,
#          -0.01163397, -0.03805806],
#         [ 0.04297458,  0.01189159, -0.0050053 , -0.04789938,
#           0.04033569, -0.02460725, -0.02637721,  0.03578104,
#           0.00376084, -0.04058083],
#         [-0.04713572, -0.0093241 ,  0.01678045, -0.00833632,
#          -0.01727923, -0.01278334, -0.0169067 ,  0.04880153,
#           0.03726616, -0.01656634]],
#
#        [[ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.01345137,  0.03700818, -0.00285297, -0.03146731,
#          -0.01209704,  0.0461374 , -0.04498342,  0.01002345,
#           0.04747726,  0.04176629],
#         [-0.00119954,  0.00754031, -0.02320751, -0.02083316,
#          -0.02938679, -0.02263305, -0.00044809, -0.01561417,
#           0.0045653 , -0.04607263],
#         [ 0.04297458,  0.01189159, -0.0050053 , -0.04789938,
#           0.04033569, -0.02460725, -0.02637721,  0.03578104,
#           0.00376084, -0.04058083],
#         [ 0.02559346,  0.04780613, -0.00981395,  0.00117517,
#          -0.01640122,  0.02806966, -0.03058835, -0.03590671,
#          -0.04262201, -0.02056714]],
#
#        [[ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04329247, -0.03832855, -0.03937177,  0.03981363,
#           0.03888757, -0.03790238, -0.02280264, -0.01040503,
#           0.03670535,  0.03162915],
#         [ 0.01922223, -0.00966435,  0.02557561, -0.04501992,
#           0.0328703 ,  0.03384738,  0.04839352,  0.04122153,
#           0.0049832 , -0.02270994],
#         [-0.01387513,  0.04310607, -0.02967048, -0.04893319,
#          -0.02841283, -0.01366446, -0.01925278, -0.03070314,
#           0.00175672, -0.03830572],
#         [-0.02255349,  0.0086275 , -0.02136222, -0.02723967,
#           0.0216015 ,  0.01926234, -0.00152051, -0.0024916 ,
#          -0.00316379, -0.01554837],
#         [-0.02373709, -0.03568146,  0.047642  , -0.02522683,
#          -0.00795456,  0.00066092,  0.02473751, -0.02829149,
#          -0.00703146, -0.02780459]],
#
#        [[ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04329247, -0.03832855, -0.03937177,  0.03981363,
#           0.03888757, -0.03790238, -0.02280264, -0.01040503,
#           0.03670535,  0.03162915],
#         [ 0.01922223, -0.00966435,  0.02557561, -0.04501992,
#           0.0328703 ,  0.03384738,  0.04839352,  0.04122153,
#           0.0049832 , -0.02270994],
#         [-0.01387513,  0.04310607, -0.02967048, -0.04893319,
#          -0.02841283, -0.01366446, -0.01925278, -0.03070314,
#           0.00175672, -0.03830572],
#         [ 0.01351022, -0.0040316 , -0.01990204,  0.02932657,
#           0.03598328,  0.0376564 , -0.01283402,  0.02749049,
#          -0.00268214,  0.01651892]],
#
#        [[ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.03160233,  0.0206942 ,  0.04009679,  0.04599464,
#           0.04222455, -0.04865545, -0.04741912,  0.03753526,
#           0.03093598, -0.03672844],
#         [ 0.01345137,  0.03700818, -0.00285297, -0.03146731,
#          -0.01209704,  0.0461374 , -0.04498342,  0.01002345,
#           0.04747726,  0.04176629],
#         [-0.00997376,  0.03778524, -0.00448792, -0.01500515,
#           0.04341942,  0.00010741, -0.02051702,  0.04234744,
#           0.04414961,  0.01972171],
#         [ 0.04297458,  0.01189159, -0.0050053 , -0.04789938,
#           0.04033569, -0.02460725, -0.02637721,  0.03578104,
#           0.00376084, -0.04058083],
#         [-0.03414679, -0.0193517 , -0.04624216, -0.03922843,
#          -0.00943142,  0.03987317,  0.0199417 ,  0.0029942 ,
#          -0.04001097,  0.03091617]],
#
#        [[ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.00681888, -0.0436577 ,  0.04286722,  0.00309669,
#          -0.04696844,  0.04180405,  0.01860786, -0.00209169,
#          -0.00467046, -0.00165581],
#         [-0.00890668,  0.00892813,  0.00207783,  0.00606325,
#          -0.00562996, -0.02168199,  0.04559488, -0.02763052,
#          -0.00834808, -0.01580008],
#         [ 0.02002009,  0.00737953,  0.00636918,  0.03727711,
#           0.03831835,  0.0231157 ,  0.00342299, -0.0338719 ,
#          -0.04451214, -0.04224399],
#         [-0.02255349,  0.0086275 , -0.02136222, -0.02723967,
#           0.0216015 ,  0.01926234, -0.00152051, -0.0024916 ,
#          -0.00316379, -0.01554837]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 4652,  613, 9082, 5631])

# %%
model.predict(embedded_docs[0].reshape(1, -1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# array([[[ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.04668584,  0.01886242, -0.04400178, -0.04621819,
#          -0.02814158, -0.02596132,  0.02865079,  0.0103706 ,
#           0.04089031,  0.03408051],
#         [ 0.01345137,  0.03700818, -0.00285297, -0.03146731,
#          -0.01209704,  0.0461374 , -0.04498342,  0.01002345,
#           0.04747726,  0.04176629],
#         [ 0.00119399,  0.03558684, -0.04989338, -0.01004828,
#           0.00660592,  0.04408484, -0.01178395, -0.04920936,
#          -0.01163397, -0.03805806],
#         [ 0.04297458,  0.01189159, -0.0050053 , -0.04789938,
#           0.04033569, -0.02460725, -0.02637721,  0.03578104,
#           0.00376084, -0.04058083],
#         [-0.0254133 , -0.03385741,  0.02221021, -0.01097144,
#           0.01635785, -0.03091173,  0.00335266,  0.00777688,
#           0.02525807,  0.0058605 ]]], dtype=float32)
